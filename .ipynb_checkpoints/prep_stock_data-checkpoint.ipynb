# %%
import pandas as pd

# %%
amd_file = "data/AMD_stock.csv"
google_file = "data/Google_stock.csv"
hp_file = "data/HP_stock.csv"
intel_file = "data/Intel_stock.csv"
tesla_file = "data/Tesla_stock.csv"

amd = pd.read_csv(amd_file)
google = pd.read_csv(google_file)
hp = pd.read_csv(hp_file)
intel = pd.read_csv(intel_file)
tesla = pd.read_csv(tesla_file)

# %%
tech_list = [amd, google, hp, intel, tesla]

def cal_test_data(df):
    hc = df['High'] - df['Low']
    oc = df['Close'] - df['Open']
    m_avg_7 = hc.rolling(7, min_periods=0).mean() 
    m_avg_14 = hc.rolling(14, min_periods=0).mean()
    m_avg_21 = hc.rolling(21, min_periods=0).mean()
    m_std_7 = df['Close'].rolling(7, min_periods=0).std()
    test_data = {
        "High-Low Price": hc,
        "Close-Open Price": oc,
        "7-day m_avg": m_avg_7,
        "14-day m_avg": m_avg_14,
        "21-day m_avg": m_avg_21,
        "7-day m_std": m_std_7,
    }
    test_df = pd.DataFrame(test_data)
    return test_df

# %%
cal_test_data(amd)
cal_test_data(amd).fillna(0)
# Out:
#       High-Low Price  Close-Open Price  7-day m_avg  14-day m_avg  \
# 0           0.629999          0.010000     0.629999      0.629999
# 1           0.280001         -0.020000     0.455000      0.455000
# 2           0.460000         -0.190001     0.456667      0.456667
# 3           0.380000          0.030000     0.437500      0.437500
# 4           0.330000          0.120000     0.416000      0.416000
# ...              ...               ...          ...           ...
# 1002        1.200005          0.009995     2.527143      2.815714
# 1003        2.320000         -1.330002     2.600001      2.836429
# 1004        3.029999         -1.040001     2.794286      2.850000
# 1005        2.659996          1.510002     2.585714      2.644286
# 1006        1.430000         -0.389999     2.190000      2.527858
#
#       21-day m_avg  7-day m_std
# 0         0.629999     0.000000
# 1         0.455000     0.000000
# 2         0.456667     0.109697
# 3         0.437500     0.092557
# 4         0.416000     0.100350
# ...            ...          ...
# 1002      3.009048     2.298816
# 1003      3.009048     2.138821
# 1004      3.075238     1.749579
# 1005      2.906190     0.934162
# 1006      2.825714     0.773520
#
# [1007 rows x 6 columns]

# %%
cal_test_data(google)
cal_test_data(google).fillna(0)
# Out:
#       High-Low Price  Close-Open Price  7-day m_avg  14-day m_avg  \
# 0          13.830017          7.330017    13.830017     13.830017
# 1           8.180054         -1.459961    11.005035     11.005035
# 2           9.459961          7.940002    10.490011     10.490011
# 3          15.696045         10.890015    11.791519     11.791519
# 4           7.135986          0.250000    10.860413     10.860413
# ...              ...               ...          ...           ...
# 1002       16.890015          3.849976    27.350586     31.234593
# 1003       44.393066         24.454956    31.275303     32.506243
# 1004       36.349976        -29.070068    31.736154     33.267308
# 1005       39.494995        -22.489990    32.394008     31.341239
# 1006       23.510010         16.459961    29.774013     30.092660
#
#       21-day m_avg  7-day m_std
# 0        13.830017     0.000000
# 1        11.005035     0.537408
# 2        10.490011     4.346769
# 3        11.791519     9.271221
# 4        10.860413    10.004890
# ...            ...          ...
# 1002     31.726964    12.922782
# 1003     32.793300    17.155756
# 1004     33.021391    18.298864
# 1005     33.327584    17.652768
# 1006     31.806158    17.731727
#
# [1007 rows x 6 columns]

# %%
cal_test_data(hp)
cal_test_data(google).fillna(0)
# Out:
#       High-Low Price  Close-Open Price  7-day m_avg  14-day m_avg  \
# 0          13.830017          7.330017    13.830017     13.830017
# 1           8.180054         -1.459961    11.005035     11.005035
# 2           9.459961          7.940002    10.490011     10.490011
# 3          15.696045         10.890015    11.791519     11.791519
# 4           7.135986          0.250000    10.860413     10.860413
# ...              ...               ...          ...           ...
# 1002       16.890015          3.849976    27.350586     31.234593
# 1003       44.393066         24.454956    31.275303     32.506243
# 1004       36.349976        -29.070068    31.736154     33.267308
# 1005       39.494995        -22.489990    32.394008     31.341239
# 1006       23.510010         16.459961    29.774013     30.092660
#
#       21-day m_avg  7-day m_std
# 0        13.830017     0.000000
# 1        11.005035     0.537408
# 2        10.490011     4.346769
# 3        11.791519     9.271221
# 4        10.860413    10.004890
# ...            ...          ...
# 1002     31.726964    12.922782
# 1003     32.793300    17.155756
# 1004     33.021391    18.298864
# 1005     33.327584    17.652768
# 1006     31.806158    17.731727
#
# [1007 rows x 6 columns]

# %%
cal_test_data(intel)
cal_test_data(intel).fillna(0)
# Out:
#       High-Low Price  Close-Open Price  7-day m_avg  14-day m_avg  \
# 0           0.660000         -0.010002     0.660000      0.660000
# 1           0.430000         -0.299999     0.545000      0.545000
# 2           0.410000         -0.100002     0.500000      0.500000
# 3           0.490002         -0.110001     0.497500      0.497500
# 4           0.410000          0.130001     0.480000      0.480000
# ...              ...               ...          ...           ...
# 1002        0.750000          0.470001     1.277142      1.231428
# 1003        0.779999         -0.119999     1.277142      1.163571
# 1004        4.179996          2.169998     1.717142      1.397142
# 1005        0.629997         -0.360001     1.297141      1.362856
# 1006        1.469997          1.070000     1.334284      1.387142
#
#       21-day m_avg  7-day m_std
# 0         0.660000     0.000000
# 1         0.545000     0.134349
# 2         0.500000     0.130512
# 3         0.497500     0.107393
# 4         0.480000     0.114674
# ...            ...          ...
# 1002      1.200000     2.079478
# 1003      1.208095     1.529618
# 1004      1.371904     1.083757
# 1005      1.343333     1.242216
# 1006      1.340952     1.457073
#
# [1007 rows x 6 columns]

# %%
cal_test_data(tesla)
cal_test_data(tesla).fillna(0)
# Out:
#       High-Low Price  Close-Open Price  7-day m_avg  14-day m_avg  \
# 0           0.392500          0.087500     0.392500      0.392500
# 1           0.190001          0.042500     0.291250      0.291250
# 2           0.262501          0.172501     0.281667      0.281667
# 3           0.422501          0.282501     0.316875      0.316875
# 4           0.372499          0.260000     0.328000      0.328000
# ...              ...               ...          ...           ...
# 1002        2.360001          0.649994     2.851431      2.902144
# 1003        3.830002          2.699997     3.140003      3.010002
# 1004        4.449997         -3.180008     3.555715      3.192858
# 1005        2.590012         -1.860001     3.500002      3.024288
# 1006        3.020004         -1.389999     3.237146      2.974288
#
#       21-day m_avg  7-day m_std
# 0         0.392500     0.000000
# 1         0.291250     0.022982
# 2         0.281667     0.077500
# 3         0.316875     0.215739
# 4         0.328000     0.319441
# ...            ...          ...
# 1002      2.690001     2.123658
# 1003      2.797144     3.300767
# 1004      2.948573     3.487737
# 1005      2.873811     2.763909
# 1006      2.852859     1.989628
#
# [1007 rows x 6 columns]

# %%
cal_test_data(amd).to_csv("test_data/test_amd.csv", index=False, header=True)
cal_test_data(google).to_csv("test_data/test_google.csv", index=False, header=True)
cal_test_data(hp).to_csv("test_data/test_hp.csv", index=False, header=True)
cal_test_data(intel).to_csv("test_data/test_intel.csv", index=False, header=True)
cal_test_data(tesla).to_csv("test_data/test_tesla.csv", index=False, header=True)
